# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# %%
url = r"https://www.archiwum.gddkia.gov.pl/dane/zima_html/utrdane.xml"

# %%
response = requests.get(url)
if response.status_code == 200:
    data = response.content
    df = pd.read_xml(data, xpath='//utr')
    df.head()
else: 
    print(response.status_code)

# %%
df.head()
# Out:
#   typ nr_drogi                 woj       km     dl    geo_lat   geo_long  \
# 0   U       A1           pomorskie   35.889  7.461  53.940744  18.646039
# 1   U       A1  kujawsko-pomorskie   81.300  8.700  53.543876  18.608566
# 2   U       A1             śląskie  417.875  0.000  50.888121  19.175394
# 3   U       A1             śląskie  418.700  0.100  50.883825  19.166442
# 4   U       A1             śląskie  427.000  4.000  50.857854  19.058690
#
#                                        nazwa_odcinka  \
# 0                    węzeł Pelplin - węzeł Kopytkowo
# 1                         w. Grudziądz - w. Warlubie
# 2  Zajęcie pasa awaryjnego jezdni w kierunku na G...
# 3                  Łącznice węzła Częstochowa Północ
# 4  w. Częstochowa Północ - w. Częstochowa Jasna Góra
#
#              data_powstania           data_likwidacji  ...  \
# 0  2025-04-24T10:00:00+0200  2025-06-09T23:59:00+0200  ...
# 1  2025-05-25T09:30:00+0200  2025-07-02T00:00:00+0200  ...
# 2  2025-06-05T11:00:00+0200  2025-06-06T11:30:00+0200  ...
# 3  2025-06-05T13:00:00+0200  2025-06-06T12:00:00+0200  ...
# 4  2025-06-03T08:00:00+0200  2025-06-06T12:00:00+0200  ...
#
#   ogr_skrajnia_pozioma  ogr_skrajnia_pionowa  ogr_szerokosc ogr_predkosc  \
# 0                  NaN                   NaN            NaN          NaN
# 1                  NaN                   NaN            NaN          NaN
# 2                  NaN                   NaN            3.8        110.0
# 3                  NaN                   NaN            3.0          NaN
# 4                  NaN                   NaN            3.8         80.0
#
#    ruch_wahadlowy  sygnalizacja_swietlna  awaria_mostu  ruch_2_kierunkowy  \
# 0           False                  False         False              False
# 1           False                  False         False              False
# 2           False                  False         False              False
# 3           False                  False         False              False
# 4           False                  False         False              False
#
#    droga_zamknieta  czasy_oczekiwania
# 0            False                NaN
# 1            False                NaN
# 2            False                NaN
# 3            False                NaN
# 4            False                NaN
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   typ                    490 non-null    object
#  1   nr_drogi               490 non-null    object
#  2   woj                    490 non-null    object
#  3   km                     490 non-null    float64
#  4   dl                     490 non-null    float64
#  5   geo_lat                457 non-null    float64
#  6   geo_long               457 non-null    float64
#  7   nazwa_odcinka          490 non-null    object
#  8   data_powstania         490 non-null    object
#  9   data_likwidacji        490 non-null    object
#  10  objazd                 481 non-null    object
#  11  objazd_mapy            0 non-null      float64
#  12  rodzaj                 0 non-null      float64
#  13  skutki                 23 non-null     object
#  14  ogr_nosnosc            3 non-null      float64
#  15  ogr_nacisk             2 non-null      float64
#  16  ogr_skrajnia_pozioma   103 non-null    float64
#  17  ogr_skrajnia_pionowa   5 non-null      float64
#  18  ogr_szerokosc          49 non-null     float64
#  19  ogr_predkosc           299 non-null    float64
#  20  ruch_wahadlowy         464 non-null    object
#  21  sygnalizacja_swietlna  464 non-null    object
#  22  awaria_mostu           464 non-null    object
#  23  ruch_2_kierunkowy      464 non-null    object
#  24  droga_zamknieta        464 non-null    object
#  25  czasy_oczekiwania      0 non-null      float64
# dtypes: float64(13), object(13)
# memory usage: 99.7+ KB
